# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import warnings

# %%
warnings.filterwarnings("ignore")
! pip install geedim

# %%
import os
os.chdir("/content/drive/MyDrive/Gates Foundation/Building Dataset Validation/")

# %%
! ls configs/
# raster_data_configs.yaml
# Out:
# data_configs.yaml	      validation_config_curacao.yaml
# open_buildings_temporal.yaml  validation_config_juba.yaml
# raster_data_configs.yaml      validation_configs.yaml

# %%
from src.raster import run_pipeline, load_config, load_all_aois
from pathlib import Path

config = load_config(Path("configs/raster_data_configs.yaml"))
datasets = load_all_aois(config)
run_pipeline(config, datasets=datasets)

print("Pipeline complete.")
# Out:
# 2026-03-31 19:11:42 | INFO | Raster_Downloader | Loaded 54 dataset(s) from inventory.
# INFO:Raster_Downloader:Loaded 54 dataset(s) from inventory.
# 2026-03-31 19:11:46 | INFO | Raster_Downloader | Earth Engine initialised.
# INFO:Raster_Downloader:Earth Engine initialised.
# 2026-03-31 19:11:46 | INFO | Raster_Downloader | ── Dataset: ant-curacao | slug: ant_curacao | sources: ['google_open_buildings_temporal', 'microsoft_tempo', 'ghsl']
# INFO:Raster_Downloader:── Dataset: ant-curacao | slug: ant_curacao | sources: ['google_open_buildings_temporal', 'microsoft_tempo', 'ghsl']
# 2026-03-31 19:11:46 | INFO | Raster_Downloader |   ── google_open_buildings_temporal ──
# INFO:Raster_Downloader:  ── google_open_buildings_temporal ──
# 2026-03-31 19:11:47 | INFO | Raster_Downloader |   [OBT] ant-curacao 2016 — exists, skipping.
# INFO:Raster_Downloader:  [OBT] ant-curacao 2016 — exists, skipping.
# ...
