# %% [markdown]
# # 00 Download

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.chdir("/content/drive/MyDrive/Gates Foundation/Building Dataset Validation/")

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# ! pip install geedim

# %%
from src.plots.visualize import build_inventory_map
from IPython.display import display

BASE = "/content/drive/MyDrive/Gates Foundation/Building Dataset Validation"

m = build_inventory_map(
    csv_path = f"{BASE}/data/02_interim/aoi_tracker.csv",
    base_dir = f"{BASE}/",
    out_html = f"{BASE}/reference_inventory/dataset_inventory_map.html",
)

# display inline
display(m)
# Out:
# [SKIP] zaf-capetown: no geometry and no known centroid
# Map saved → /content/drive/MyDrive/Gates Foundation/Building Dataset Validation/reference_inventory/dataset_inventory_map.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7c7affe5d572b211e042edbbde16408e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div style=&quot;
#         position: fixed; top: 10px; right: 10px; z-index: 1000;
#         background: rgba(17,24,39,0.92); border: 1px solid #1e2d45;
#         padding: 14px 18px; font-family: monospace; font-size: 12px;
#         color: #e2e8f0; min-width: 180px; backdrop-filter: blur(4px);
#     &quot;&gt;
#       &lt;div style=&quot;font-size:11px; color:#64748b; text-transform:uppercase;
#                   letter-spacing:0.1em; margin-bottom:10px;&quot;&gt;
#         Dataset Inventory
#       &lt;/div&gt;
#       &lt;div style=&quot;margin-bottom:6px;&quot;&gt;
#         &lt;span style=&quot;color:#64748b;&quot;&gt;Total datasets&lt;/span&gt;&lt;br&gt;
#         &lt;b style=&quot;font-size:20px; color:#00e5ff;&quot;&gt;86&lt;/b&gt;
#       &lt;/div&gt;
#       &lt;div style=&quot;margin-bottom:6px;&quot;&gt;
#         &lt;span style=&quot;color:#64748b;&quot;&gt;Full coverage&lt;/span&gt;&lt;br&gt;
#         &lt;b style=&quot;font-size:18px; color:#a8ff3e;&quot;&gt;86&lt;/b&gt;
#       &lt;/div&gt;
#       &lt;div&gt;
#         &lt;span style=&quot;color:#64748b;&quot;&gt;Partial&lt;/span&gt;&lt;br&gt;
#         &lt;b style=&quot;font-size:18px; color:#fbbf24;&quot;&gt;0&lt;/b&gt;
#       &lt;/div&gt;
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7c7affe5d572b211e042edbbde16408e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7c7affe5d572b211e042edbbde16408e = L.map(
#                 &quot;map_7c7affe5d572b211e042edbbde16408e&quot;,
#                 {
#                     center: [15.0, 20.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_7c7affe5d572b211e042edbbde16408e);
#
#
#
#
#
#             var tile_layer_6a8de7a75aa6725c2faf31b155025566 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6a8de7a75aa6725c2faf31b155025566.addTo(map_7c7affe5d572b211e042edbbde16408e);
#
#
#             var feature_group_b3b08ffd882b5fa069a4255998d035cb = L.featureGroup(
#                 {
# }
#             );
#
#
#             var circle_marker_c2f25a6a004bc952ac4cc88156e85f1c = L.circleMarker(
#                 [34.53, 69.17],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#00e5ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#00e5ff&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 9.5, &quot;stroke&quot;: true, &quot;weight&quot;: 1.5}
#             ).addTo(feature_group_b3b08ffd882b5fa069a4255998d035cb);
#
#
#         var popup_38a9a1f6ff1ebe3b83d9bcf63e37b5f7 = L.popup({
#   &quot;maxWidth&quot;: 260,
# });
#
#
#
#                 var html_1035a4133f9b4ac211dc638ac0e61c69 = $(`&lt;div id=&quot;html_1035a4133f9b4ac211dc638ac0e61c69&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;div style=&quot;font-family:monospace; font-size:12px; min-width:200px;&quot;&gt;           &lt;b style=&quot;font-size:14px; color:#00e5ff;&quot;&gt;afg-ayabak&lt;/b&gt;&lt;br&gt;&lt;br&gt;           &lt;table style=&quot;width:100%; border-collapse:collapse;&quot;&gt;             &lt;tr&gt;&lt;td style=&quot;color:#888;&quot;&gt;Status&lt;/td&gt;                 &lt;td&gt;&lt;b style=&quot;color:#a8ff3e;&quot;&gt;Full&lt;/b&gt;&lt;/td&gt;&lt;/tr&gt;             &lt;tr&gt;&lt;td style=&quot;color:#888;&quot;&gt;AOI files&lt;/td&gt;&lt;td&gt;&lt;b&gt;1&lt;/b&gt;&lt;/td&gt;&lt;/tr&gt;             &lt;tr&gt;&lt;td style=&quot;color:#888;&quot;&gt;Ref files&lt;/td&gt;&lt;td&gt;&lt;b&gt;0&lt;/b&gt;&lt;/td&gt;&lt;/tr&gt;             &lt;tr&gt;&lt;td style=&quot;color:#888;&quot;&gt;Match score&lt;/td&gt;&lt;td&gt;&lt;b&gt;100%&lt;/b&gt;&lt;/td&gt;&lt;/tr&gt;             &lt;tr&gt;&lt;td style=&quot;color:#888;&quot;&gt;Has AOI&lt;/td&gt;                 &lt;td&gt;&lt;b style=&quot;color:#a8ff3e;&quot;&gt;✓&lt;/b&gt;&lt;/td&gt;&lt;/tr&gt;             &lt;tr&gt;&lt;td style=&quot;color:#888;&quot;&gt;Has Ref&lt;/td&gt;                 &lt;td&gt;&lt;b style=&quot;color:#a8ff3e;&quot;&gt;✓&lt;/b&gt;&lt;/td&gt;&lt;/tr&gt;           &lt;/table&gt;         &lt;/div&gt;         &lt;/div&gt;`)[0];
#                 popup_38a9a1f6ff1ebe3b83d9bcf63e37b5f7.setConte

# %% [markdown]
# ## Vector Datasets
# Global Building Footprints
#
# Sources:
# 1. Overture
# 2. Global Building Atlas
# 3. GloBFP

# %%
from src.downloader import UrbanDownloader

# %%
# !pwd
# Out:
# /content/drive/.shortcut-targets-by-id/1xTSKkjN4wft_0kljbwaAGKjTGEBsHZm1/Gates Foundation/Building Dataset Validation

# %%
BASE = "/content/drive/MyDrive/Gates Foundation/Building Dataset Validation"
CONFIG = f"{BASE}/configs/data_configs.yaml"
UrbanDownloader(CONFIG).download_vector()
# Out:
# [capetown_aoi.geojson] fixing 1 invalid geometries...
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# Tagged buildings: 168710 total, 168710 matched sub-AOIs, 0 dropped (in gaps)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# Tagged buildings: 123329 total, 123329 matched sub-AOIs, 0 dropped (in gaps)
# Downloading tile file: 871_17.5_-33.75_18.75_-32.5_SF.zip (20.7 MB)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# Downloading tile file: 873_17.5_-35.0_18.75_-33.75_SF.zip (147.1 MB)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# Downloading tile file: 874_18.75_-35.0_20.0_-33.75_SF.zip (41.4 MB)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# Tagged buildings: 185309 total, 185309 matched sub-AOIs, 0 dropped (in gaps)
# {'zaf-capetown': ['/content/drive/MyDrive/Gates Foundation/Building Dataset Validation/data/01_raw/zaf-capetown/vector/zaf_capetown_gba.parquet',
#   '/content/drive/MyDrive/Gates Foundation/Building Dataset Validation/data/01_raw/zaf-capetown/vector/zaf_capetown_overture_building.parquet',
#   '/content/drive/MyDrive/Gates Foundation/Building Dataset Validation/data/01_raw/zaf-capetown/vector/zaf_capetown_globfp.parquet']}

# %% [markdown]
# ## Raster Datasets
# 1. Google Open Building Temporal 2.5D
# 2. TEMPO
# 3. WSF-Tracker
# 4. GHSL Built-up and Height

# %%
BASE = "/content/drive/MyDrive/Gates Foundation/Building Dataset Validation"
CONFIG = f"{BASE}/configs/data_configs.yaml" 
UrbanDownloader(CONFIG).download_raster()
